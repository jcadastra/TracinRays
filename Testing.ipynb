# %% [markdown]
# ## Testing Your Ray Tracer
# See the [assignment docs](https://www.cs.cornell.edu/courses/cs4620/2024fa/assignments/docs/category/assignment-4) for details on our recommended path to completing the assignment.
#
# This notebook may prove useful for testing out your ray tracer.

# %%
from ExampleSceneDef import *
from TowerScene import *
# Out:
# /home/cynthiasun/.local/lib/python3.10/site-packages/numpy/_core/getlimits.py:548: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)

# %%
 # im = TransparencyExample().render(output_shape = [144,256]).GetFloatCopy()
 # im.show()

# %%
#im = SkyboxExample().render(output_shape = [144,256]).GetFloatCopy()
#im.show()

# %%
im = Tower().render(output_shape = [100,100]).GetFloatCopy()
im.show()
# im.writeToFile("Tower.png")

# %%
# im = RectangularExample().render(output_shape=[144,256]).GetFloatCopy()
# im.show()

# %%
# im = CylinderExample().render(output_shape = [144,256]).GetFloatCopy()
# im.show()

# %%
 # im = ConeExample().render(output_shape = [144,256]).GetFloatCopy()
 # im.show()

# %% [markdown]
# ### Step 0
# When you have completed Step 0 your the image below should look like:
# ![Step0](./ref/step0.png)

# %%
# im = OrthoFriendlyExample().render()
# im.show()
# # im.writeToFile("OrthoFriendlyExample.png")
# ref = Image(path="./ref/step0.png");
# print("Max diff with reference is {}".format(np.abs(ref.pixels-im.pixels).max()))
# ref.show()
# diff = Image(pixels=np.abs(ref.pixels-im.pixels))
# diff.show()

# %% [markdown]
# ### Step 1
# When you have completed Step 0 your the image below should look like:
# ![Step1](./ref/step1.png)

# %%
# im = TwoSpheresExample().render(output_shape = [144,256]).GetFloatCopy()
# im.show()

# ref = Image(path="./ref/step1.png").GetFloatCopy();
# ref.show()
# print("Max diff with reference is {}".format(np.abs(ref.pixels-im.pixels).max()))
# diff = Image(pixels=np.abs(ref.pixels-im.pixels))
# diff.show()

# %% [markdown]
# ### Step 2-7
# See the [assignment docs](https://www.cs.cornell.edu/courses/cs4620/2023fa/assignments/docs/category/assignment-4)
#
# The code in the three cells below can be used to test out each of three different test scenes

# %%
# im = TwoSpheresExample().render(output_shape = [144,256])
# im.show()

# %%
# im = ThreeSpheresExample().render(output_shape = [144,256]).GetFloatCopy()
# im.show()
# ref = Image(path="./ref/step7.png").GetFloatCopy();
# ref.show()
# print("Max diff with reference is {}".format(np.abs(ref.pixels-im.pixels).max()))
# diff = Image(pixels=np.abs(ref.pixels-im.pixels))
# diff.show()

# %%
# im = CubeExample().render(output_shape=[144,256]).GetFloatCopy()
# im.show()
# ref = Image(path="./ref/step6.png").GetFloatCopy();
# ref.show()
# print("Max diff with reference is {}".format(np.abs(ref.pixels-im.pixels).max()))
# diff = Image(pixels=np.abs(ref.pixels-im.pixels))
# diff.show()
