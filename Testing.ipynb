# %% [markdown]
# ## Testing Your Ray Tracer
# See the [assignment docs](https://www.cs.cornell.edu/courses/cs4620/2024fa/assignments/docs/category/assignment-4) for details on our recommended path to completing the assignment.
#
# This notebook may prove useful for testing out your ray tracer.

# %%
from ExampleSceneDef import *

# %% [markdown]
# ### Step 0
# When you have completed Step 0 your the image below should look like:
# ![Step0](./ref/step0.png)

# %%
im = OrthoFriendlyExample().render()
im.show()
# im.writeToFile("OrthoFriendlyExample.png")

# %% [markdown]
# ### Step 1
# When you have completed Step 0 your the image below should look like:
# ![Step1](./ref/step1.png)

# %%
im = TwoSpheresExample().render(output_shape = [144,256])
im.show()

# ref = Image(path="./ref/step1.png").GetFloatCopy();
# ref.show()
# print("Max diff with reference is {}".format(np.abs(ref.pixels-im.pixels).max()))

# %% [markdown]
# ### Step 2-7
# See the [assignment docs](https://www.cs.cornell.edu/courses/cs4620/2023fa/assignments/docs/category/assignment-4)
#
# The code in the three cells below can be used to test out each of three different test scenes

# %%
im = TwoSpheresExample().render(output_shape = [144,256])
im.show()

# %%
im = ThreeSpheresExample().render(output_shape = [144,256])
im.show()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 im = ThreeSpheresExample().render(output_shape = [144,256])
#       2 im.show()
#
# File ~/CS4620/A4/ExampleSceneDef.py:18, in ExampleSceneDef.render(self, output_path, output_shape, gamma_correct, srgb_whitepoint)
#      16 if(srgb_whitepoint is None):
#      17     srgb_whitepoint = 1.0;
# ---> 18 pix = ray.render_image(self.camera, self.scene, self.lights, output_shape[1], output_shape[0]);
#      19 im = None;
#      20 if(gamma_correct):
#
# File ~/CS4620/A4/ray.py:371, in render_image(camera, scene, lights, nx, ny)
#     368         #ray = Ray(vec([1-(2*i/ny), 1-(2*j/nx), 0]), vec([0,0,-1]))
#     369         intersection = scene.intersect(ray)  # this will return a Hit object
# --> 371         output_image[i, j] = shade(ray, intersection, scene, lights)
#     372         # set the output pixel color if an intersection is found
#     373         #if intersection is not no_hit:
#     374         #    output_image[i, j] = vec([1.0, 1.0, 1.0])
#     375         #else:
#     376         #    output_image[i, j] = vec([0.0, 0.0, 0.0])
#     378 return output_image
#
# File ~/CS4620/A4/ray.py:340, in shade(ray, hit, scene, lights, depth)
#     338 r = 2 * np.dot(n,v) * n - v
#     339 reflected = Ray(hit.point, r)
# --> 340 mirror = hit.material.k_m * shade(reflected, hit, scene, lights, depth+1)
#     343 direct = vec([0,0,0])
#     344 for light in lights:
#
# File ~/CS4620/A4/ray.py:340, in shade(ray, hit, scene, lights, depth)
#     338 r = 2 * np.dot(n,v) * n - v
#     339 reflected = Ray(hit.point, r)
# --> 340 mirror = hit.material.k_m * shade(reflected, hit, scene, lights, depth+1)
#     343 direct = vec([0,0,0])
#     344 for light in lights:
#
#     [... skipping similar frames: shade at line 340 (2963 times)]
#
# File ~/CS4620/A4/ray.py:340, in shade(ray, hit, scene, lights, depth)
#     338 r = 2 * np.dot(n,v) * n - v
#     339 reflected = Ray(hit.point, r)
# --> 340 mirror = hit.material.k_m * shade(reflected, hit, scene, lights, depth+1)
#     343 direct = vec([0,0,0])
#     344 for light in lights:
#
# File ~/CS4620/A4/ray.py:337, in shade(ray, hit, scene, lights, depth)
#     334     mirror = scene.bg_color
#     336 n = hit.normal
# --> 337 v = -normalize(ray.direction)
#     338 r = 2 * np.dot(n,v) * n - v
#     339 reflected = Ray(hit.point, r)
#
# File ~/CS4620/A4/utils.py:10, in normalize(v)
#       8 def normalize(v):
#       9     """Return a unit vector in the direction of the vector v."""
# ---> 10     return v / np.linalg.norm(v)
#
# File ~/miniconda3/envs/4620-A3/lib/python3.10/site-packages/numpy/linalg/_linalg.py:2779, in norm(x, ord, axis, keepdims)
#    2626 """
#    2627 Matrix or vector norm.
#    2628
#    (...)
#    2775
#    2776 """
#    2777 x = asarray(x)
# -> 2779 if not issubclass(x.dtype.type, (inexact, object_)):
#    2780     x = x.astype(float)
#    2782 # Immediately handle some default, simple, fast, and common cases.
#
# RecursionError: maximum recursion depth exceeded in __subclasscheck__

# %%
im = CubeExample().render(output_shape=[144,256])
im.show()
