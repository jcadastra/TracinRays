# %% [markdown]
# ## Testing Your Ray Tracer
# See the [assignment docs](https://www.cs.cornell.edu/courses/cs4620/2024fa/assignments/docs/category/assignment-4) for details on our recommended path to completing the assignment.
#
# This notebook may prove useful for testing out your ray tracer.

# %%
from ExampleSceneDef import *

# %% [markdown]
# ### Step 0
# When you have completed Step 0 your the image below should look like:
# ![Step0](./ref/step0.png)

# %%
im = OrthoFriendlyExample().render()
im.show()
# im.writeToFile("OrthoFriendlyExample.png")

# %% [markdown]
# ### Step 1
# When you have completed Step 0 your the image below should look like:
# ![Step1](./ref/step1.png)

# %%
im = TwoSpheresExample().render(output_shape = [144,256])
im.show()

# ref = Image(path="./ref/step1.png").GetFloatCopy();
# ref.show()
# print("Max diff with reference is {}".format(np.abs(ref.pixels-im.pixels).max()))

# %% [markdown]
# ### Step 2-7
# See the [assignment docs](https://www.cs.cornell.edu/courses/cs4620/2023fa/assignments/docs/category/assignment-4)
#
# The code in the three cells below can be used to test out each of three different test scenes

# %%
im = TwoSpheresExample().render(output_shape = [144,256])
im.show()

# %%
im = ThreeSpheresExample().render(output_shape = [144,256])
im.show()

# %%
im = CubeExample().render([144,256])
im.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 im = CubeExample().render([144,256])
#       2 im.show()
#
# File ~/CS4620/A4/ExampleSceneDef.py:18, in ExampleSceneDef.render(self, output_path, output_shape, gamma_correct, srgb_whitepoint)
#      16 if(srgb_whitepoint is None):
#      17     srgb_whitepoint = 1.0;
# ---> 18 pix = ray.render_image(self.camera, self.scene, self.lights, output_shape[1], output_shape[0]);
#      19 im = None;
#      20 if(gamma_correct):
#
# File ~/CS4620/A4/ray.py:357, in render_image(camera, scene, lights, nx, ny)
#     353         intersection = scene.intersect(ray)  # this will return a Hit object
#     355         output_image[i, j] = shade(ray, intersection, scene, lights)
#     356         # set the output pixel color if an intersection is found
# --> 357         #if intersection is not no_hit:
#     358         #    output_image[i, j] = vec([1.0, 1.0, 1.0])
#     359         #else:
#     360         #    output_image[i, j] = vec([0.0, 0.0, 0.0])
#     362 return output_image
#
# File ~/CS4620/A4/ray.py:301, in Scene.intersect(self, ray)
#     298 closest_t = np.inf
#     300 for surf in self.surfs:
# --> 301     hit = surf.intersect(ray)
#     303     if hit and hit.t < closest_t:
#     304         closest_hit = hit
#
# File ~/CS4620/A4/ray.py:147, in Triangle.intersect(self, ray)
#     139 """Computes the intersection between a ray and this triangle, if it exists.
#     140
#     141 Parameters:
#    (...)
#     144   Hit -- the hit data
#     145 """
#     146 # TODO A4 implement this function
# --> 147 A = np.matrix(self.vs[0] - self.vs[1], self.vs[0] - self.vs[2], ray.direction)
#     148 b = np.matrix(self.vs[0] - ray.origin)
#     149 x = np.linalg.solve(A, b)
#
# File ~/miniconda3/envs/4620-A3/lib/python3.10/site-packages/numpy/matrixlib/defmatrix.py:136, in matrix.__new__(subtype, data, dtype, copy)
#     134     intype = data.dtype
#     135 else:
# --> 136     intype = N.dtype(dtype)
#     137 new = data.view(subtype)
#     138 if intype != data.dtype:
#
# TypeError: Cannot construct a dtype from an array
